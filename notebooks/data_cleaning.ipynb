# %%
df = spark.read.format("csv") \
            .option("header",True) \
            .option("inferSchema", True) \
            .load("abfss://5523ca1d-23b4-4a5f-be21-01322d51f258@onelake.dfs.fabric.microsoft.com/f4319035-17a8-49d4-9c13-6fca8e36be94/Files/StockItems.csv")
display(df)
# Out:
# StatementMeta(, 20aed68a-15a9-430b-a79a-8da85e9ed38e, 3, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 5e443a0c-6650-4bc8-93a3-1e2adbbede80)

# %%
df = df.drop('Brand', 'Size')
display(df)
# Out:
# StatementMeta(, 20aed68a-15a9-430b-a79a-8da85e9ed38e, 4, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 563674fe-d968-4ad6-94e4-df4e2e8f682f)

# %%
df.write.mode("overwrite").format("delta").saveAsTable("silver.StockItems")
# Out:
# StatementMeta(, 20aed68a-15a9-430b-a79a-8da85e9ed38e, 5, Finished, Available, Finished, False)
